# %% [markdown]
# ## Assignment 4 : Perform EDA on Dataset.
# ## Name : Gaurav Bhogale
# ## Registration ID: SIRSS2101

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("D:\COVID-19_India_Data.csv")

# %%
data.head(25)
# Out:
#    Date_reported  new_cases  cum_cases  new_death  cum_death  cum_recovered  \
# 0     2020-01-30          1          1          0          0              0
# 1     2020-01-31          0          1          0          0              0
# 2     2020-02-01          0          1          0          0              0
# 3     2020-02-02          1          2          0          0              0
# 4     2020-02-03          1          3          0          0              0
# 5     2020-02-04          0          3          0          0              0
# 6     2020-02-05          0          3          0          0              0
# 7     2020-02-06          0          3          0          0              0
# 8     2020-02-07          0          3          0          0              0
# 9     2020-02-08          0          3          0          0              0
# 10    2020-02-09          0          3          0          0              0
# ...

# %%
data.tail()
# Out:
#     Date_reported  new_cases  cum_cases  new_death  cum_death  cum_recovered  \
# 574    2021-08-26      44658   32603188        496     436861       31821428
# 575    2021-08-27      46759   32649947        509     437370       31852802
# 576    2021-08-28      45083   32695030        460     437830       31888642
# 577    2021-08-29      42909   32737939        380     438210       31923405
# 578    2021-08-30      30941   32768880        350     438560       31959680
#
#      cum_active_cases
# 574            344899
# 575            359775
# 576            368558
# 577            376324
# 578            370640

# %%
data.shape
# Out:
# (579, 7)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date_reported     579 non-null    object
#  1   new_cases         579 non-null    int64
#  2   cum_cases         579 non-null    int64
#  3   new_death         579 non-null    int64
#  4   cum_death         579 non-null    int64
#  5   cum_recovered     579 non-null    int64
#  6   cum_active_cases  579 non-null    int64
# dtypes: int64(6), object(1)
# memory usage: 31.8+ KB

# %%
data.describe()
# Out:
#            new_cases     cum_cases    new_death      cum_death  cum_recovered  \
# count     579.000000  5.790000e+02   579.000000     579.000000   5.790000e+02
# mean    56595.647668  1.053530e+07   757.443869  141742.215889   9.807313e+06
# std     81881.440898  1.083387e+07  1029.278589  137074.505736   1.038847e+07
# min     -1858.000000  1.000000e+00   -39.000000       0.000000   0.000000e+00
# 25%     10952.000000  4.481990e+05   120.000000   14243.500000   2.534375e+05
# 50%     35551.000000  8.814579e+06   448.000000  129635.000000   8.205728e+06
# 75%     61704.000000  1.299456e+07   903.500000  167252.000000   1.188234e+07
# max    414188.000000  3.276888e+07  7374.000000  438560.000000   3.195968e+07
#
#        cum_active_cases
# count      5.790000e+02
# mean       5.862402e+05
# std        7.833744e+05
# min        0.000000e+00
# 25%        1.434610e+05
# 50%        3.735420e+05
# 75%        6.791970e+05
# max        3.745237e+06

# %%
data.nunique()
# Out:
# Date_reported       579
# new_cases           538
# cum_cases           547
# new_death           432
# cum_death           528
# cum_recovered       531
# cum_active_cases    547
# dtype: int64

# %%
data.columns
# Out:
# Index(['Date_reported', 'new_cases', 'cum_cases', 'new_death', 'cum_death',
#        'cum_recovered', 'cum_active_cases'],
#       dtype='object')

# %%
data['Date_reported'].unique()
# Out:
# array(['2020-01-30', '2020-01-31', '2020-02-01', '2020-02-02',
#        '2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06',
#        '2020-02-07', '2020-02-08', '2020-02-09', '2020-02-10',
#        '2020-02-11', '2020-02-12', '2020-02-13', '2020-02-14',
#        '2020-02-15', '2020-02-16', '2020-02-17', '2020-02-18',
#        '2020-02-19', '2020-02-20', '2020-02-21', '2020-02-22',
#        '2020-02-23', '2020-02-24', '2020-02-25', '2020-02-26',
#        '2020-02-27', '2020-02-28', '2020-02-29', '2020-03-01',
#        '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#        '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09',
#        '2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13',
#        '2020-03-14', '2020-03-15', '2020-03-16', '2020-03-17',
#        '2020-03-18', '2020-03-19', '2020-03-20', '2020-03-21',
#        '2020-03-22', '2020-03-23', '2020-03-24', '2020-03-25',
#        '2020-03-26', '2020-03-27', '2020-03-28', '2020-03-29',
# ...

# %%
data['cum_death'].unique()
# Out:
# array([     0,      1,      2,      3,      4,      5,      7,     10,
#            12,     20,     24,     27,     32,     35,     58,     72,
#            86,     99,    136,    150,    178,    226,    246,    288,
#           331,    358,    393,    405,    448,    486,    521,    559,
#           592,    645,    681,    721,    780,    825,    881,    939,
#          1008,   1079,   1154,   1223,   1323,   1391,   1566,   1693,
#          1785,   1889,   1985,   2101,   2212,   2294,   2415,   2551,
#          2649,   2753,   2871,   3025,   3156,   3302,   3434,   3584,
#          3726,   3868,   4024,   4172,   4344,   4534,   4711,   4980,
#          5185,   5408,   5608,   5829,   6088,   6363,   6649,   6946,
#          7207,   7473,   7750,   8102,   8498,   8884,   9195,   9520,
#          9900,  11903,  12237,  12573,  12948,  13254,  13699,  14011,
#         14476,  14894,  15301,  15685,  16095,  16475,  16893,  17400,
# ...

# %%
data.isnull().sum()
# Out:
# Date_reported       0
# new_cases           0
# cum_cases           0
# new_death           0
# cum_death           0
# cum_recovered       0
# cum_active_cases    0
# dtype: int64

# %%
ratio=['new_cases','cum_cases','new_death','cum_death','cum_recovered','cum_active_cases']
for values in ratio:
    data[values].plot(kind='hist')
    plt.title('{valname}'.format(valname=values))
    plt.show()

# %%
sns.pairplot(data[['new_cases','cum_cases','new_death','cum_death','cum_recovered','cum_active_cases']])

# %%
sns.distplot(data['new_cases'])
# Out:
# C:\Users\gaura\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='new_cases', ylabel='Density'>

# %%
sns.distplot(data['cum_cases'])
# Out:
# C:\Users\gaura\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cum_cases', ylabel='Density'>

# %%
sns.distplot(data['new_death'])
# Out:
# C:\Users\gaura\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='new_death', ylabel='Density'>

# %%
sns.distplot(data['cum_death'])
# Out:
# C:\Users\gaura\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cum_death', ylabel='Density'>

# %%
sns.distplot(data['cum_recovered'])
# Out:
# C:\Users\gaura\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cum_recovered', ylabel='Density'>

# %%
sns.distplot(data['cum_active_cases'])
# Out:
# C:\Users\gaura\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cum_active_cases', ylabel='Density'>

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(),annot=True);
